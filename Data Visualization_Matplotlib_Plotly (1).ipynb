# %%
import matplotlib as plt 
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.randn(1000), columns= ['data'], (index : pd.date_range('2022/03/26'), period = 1000))
# Out:
#   File "C:\Users\Jalpa\AppData\Local\Temp/ipykernel_10280/3321464379.py", line 1
#     df = pd.DataFrame(np.random.randn(1000), columns= ['data'], (index : pd.date_range('2022/03/26'), period = 1000))
#                                                                        ^
# SyntaxError: invalid syntax

# %%
df
# Out:
#          data
# 0    0.828446
# 1   -0.873436
# 2    0.697849
# 3    0.275400
# 4    2.918443
# ..        ...
# 995 -1.057095
# 996 -0.238780
# 997  0.854308
# 998  1.082985
# 999  0.941358
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv('https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv')

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11].plot(kind = 'bar', figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11]
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 5            5.4          3.9           1.7          0.4  Setosa
# 6            4.6          3.4           1.4          0.3  Setosa
# 7            5.0          3.4           1.5          0.2  Setosa
# 8            4.4          2.9           1.4          0.2  Setosa
# 9            4.9          3.1           1.5          0.1  Setosa
# 10           5.4          3.7           1.5          0.2  Setosa

# %%
df.iloc[5:11].plot(kind = 'barh', figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.iloc[5:11].plot(kind = 'hist', figsize = (20,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df['sepal.length'].plot(kind = 'hist',figsize=(20,10), orientation = 'horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.hist(figsize=(20,10), color = 'r', alpha= 0.5)
# Out:
# array([[<AxesSubplot:title={'center':'sepal.length'}>,
#         <AxesSubplot:title={'center':'sepal.width'}>],
#        [<AxesSubplot:title={'center':'petal.length'}>,
#         <AxesSubplot:title={'center':'petal.width'}>]], dtype=object)

# %%
df.plot(kind = 'box', figsize=(20,10), color = {'boxes' :'b','whiskers' : 'r' })
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.plot(kind = 'area', figsize = (20,10), alpha = 0.4, stacked = False)  # alpha parameter is for constast changes
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'area', figsize = (20,10), alpha = 0.4, stacked = True)
# Out:
# <AxesSubplot:>

# %%
df.plot(figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x = 'sepal.length', y = 'petal.length', c = 'sepal.width', s = 100)
# Out:
# <AxesSubplot:xlabel='sepal.length', ylabel='petal.length'>

# %%
df.plot.scatter(x = 'sepal.length', y = 'petal.length', c = 'sepal.width', s = df['petal.length']*100)
# Out:
# <AxesSubplot:xlabel='sepal.length', ylabel='petal.length'>

# %%
df.plot.hexbin(x = 'sepal.length', y = 'petal.length', gridsize = 10)
# Out:
# <AxesSubplot:xlabel='sepal.length', ylabel='petal.length'>

# %%
df1 = df.drop(columns ='variety').iloc[0]
df1.plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='0'>

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df.iplot()
# Out:
# <div>                            <div id="e57d417e-dae2-4ec1-a022-f413c7c82ec7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x = 'sepal.length', y = 'petal.length', mode = 'markers', kind = 'scatter')
# Out:
# <div>                            <div id="51a01162-49c3-414e-bc9c-d0b76dfa554b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind = 'scatter', mode = 'markers', size = 5)
# Out:
# <div>                            <div id="aaef5178-2715-4906-853f-18ad41f5a7df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.ilpot(kind = 'bubble', x = 'sepal.length', y = 'petal.length', size ='sepal.width')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10280/3903515734.py in <module>
# ----> 1 df.ilpot(kind = 'bubble', x = 'sepal.length', y = 'petal.length', size ='sepal.width')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ilpot'

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="89d6d23d-c3d7-4d48-8730-35604ffb6a07" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.iplot(kind = 'scatter3d', x = 'sepal.length', y = 'sepal.width', z = 'petal.width')
# Out:
# <div>                            <div id="883513d7-1e0d-4ec6-ab99-8f737b5d7c18" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.head().iplot(kind = 'scatter3d', x = 'sepal.length', y = 'sepal.width', z = 'petal.width')
# Out:
# <div>                            <div id="595f6f27-ec34-4332-95d3-3d4a5fe1bfbb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
